# %%
import pandas as pd
food_nutrient = pd.read_csv("food_nutrient.csv")
duplicates = food_nutrient[food_nutrient.duplicated(subset=['fdc_id', 'name'], keep=False)]
food_nutrient = food_nutrient.drop_duplicates(subset=["fdc_id", "name"])
food_nutrient_pivot = pd.pivot(food_nutrient, index="fdc_id", columns="name", values="amount")
branded_food = pd.read_csv("branded_food.csv")
food = pd.concat([pd.read_csv("food_sample_100.csv"), pd.read_csv("food_other.csv")], ignore_index=True)
food_brands = pd.merge(food, branded_food, on="fdc_id")
food_nutrient_pivot = pd.merge(food_nutrient_pivot, food_brands, on="fdc_id")

# %%
food_nutrient_pivot[(food_nutrient_pivot["Fatty acids, total saturated"] < 1) & (food_nutrient_pivot["Fiber, total dietary"])]
# Out:
#        fdc_id   Ergosta-5,7-dienol  25-hydroxycholecalciferol  Alanine  \
# 2      345013                  NaN                        NaN      NaN
# 4      345449                  NaN                        NaN      NaN
# 7      345947                  NaN                        NaN      NaN
# 8      346321                  NaN                        NaN      NaN
# 13     347312                  NaN                        NaN      NaN
# ...       ...                  ...                        ...      ...
# 9527  2659508                  NaN                        NaN      NaN
# 9533  2660777                  NaN                        NaN      NaN
# 9535  2661380                  NaN                        NaN      NaN
# 9538  2661782                  NaN                        NaN      NaN
# 9540  2662182                  NaN                        NaN      NaN
#
#       Alcohol, ethyl  Arginine  Ash  Aspartic acid  Beta-glucan  \
# 2                NaN       NaN  1.3            NaN          NaN
# 4                NaN       NaN  2.3            NaN          NaN
# 7                NaN       NaN  0.0            NaN          NaN
# 8                NaN       NaN  NaN            NaN          NaN
# 13               NaN       NaN  NaN            NaN          NaN
# ...              ...       ...  ...            ...          ...
# 9527             NaN       NaN  NaN            NaN          NaN
# 9533             NaN       NaN  NaN            NaN          NaN
# 9535             NaN       NaN  NaN            NaN          NaN
# 9538             NaN       NaN  NaN            NaN          NaN
# 9540             NaN       NaN  NaN            NaN          NaN
#
#       Beta-sitostanol  ...                           branded_food_category  \
# 2                 NaN  ...  Cereals Products - Ready to Eat (Shelf Stable)
# 4                 NaN  ...  Cereals Products - Ready to Eat (Shelf Stable)
# 7                 NaN  ...  Cereals Products - Ready to Eat (Shelf Stable)
# 8                 NaN  ...                                             NaN
# 13                NaN  ...                                             NaN
# ...               ...  ...                                             ...
# 9527              NaN  ...                   Prepared Pasta & Pizza Sauces
# 9533              NaN  ...                 Pre-Packaged Fruit & Vegetables
# 9535              NaN  ...                        Chips, Pretzels & Snacks
# 9538              NaN  ...                               Canned Vegetables
# 9540              NaN  ...                                        Tomatoes
#
#       data_source       package_weight  modified_date  available_date  \
# 2            GDSN                  NaN     2018-01-25      2019-04-01
# 4            GDSN                  NaN     2017-11-10      2019-04-01
# 7            GDSN                  NaN     2017-12-18      2019-04-01
# 8            GDSN                  NaN     2018-11-17      2019-04-01
# 13           GDSN                  NaN     2018-11-17      2019-04-01
# ...           ...                  ...            ...             ...
# 9527           LI          24 oz/680 g     2023-09-05      2023-10-26
# 9533           LI          12 oz/340 g     2023-09-19      2023-10-26
# 9535           LI  16 oz/1 lbs/453.6 g     2023-09-07      2023-10-26
# 9538           LI         8.4 oz/240 g     2023-08-25      2023-10-26
# 9540           LI        14.5 oz/411 g     2023-09-20      2023-10-26
#
#       market_country  discontinued_date  preparation_state_code  \
# 2      United States                NaN                     NaN
# 4      United States                NaN                     NaN
# 7      United States                NaN                     NaN
# 8      United States                NaN                     NaN
# 13     United States                NaN                     NaN
# ...              ...                ...                     ...
# 9527   United States                NaN                     NaN
# 9533   United States                NaN                     NaN
# 9535   United States                NaN                     NaN
# 9538   United States                NaN                     NaN
# 9540   United States                NaN                     NaN
#
#       trade_channel  short_description
# 2               NaN                NaN
# 4               NaN                NaN
# 7               NaN                NaN
# 8               NaN                NaN
# 13              NaN                NaN
# ...             ...                ...
# 9527            NaN                NaN
# 9533            NaN                NaN
# 9535            NaN                NaN
# 9538            NaN                NaN
# 9540            NaN                NaN
#
# [2054 rows x 229 columns]
